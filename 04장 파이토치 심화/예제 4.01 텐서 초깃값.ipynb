# %%
import torch  # 파이토치 라이브러리를 임포트합니다.


x = torch.FloatTensor(  # 실수형(Float) 텐서를 생성합니다.
    [
        [-0.6577, -0.5797, 0.6360],  # 첫 번째 행 데이터 (3개의 특성)
        [0.7392, 0.2145, 1.523],    # 두 번째 행 데이터 (3개의 특성)
        [0.2432, 0.5662, 0.322]      # 세 번째 행 데이터 (3개의 특성)
    ]
)
